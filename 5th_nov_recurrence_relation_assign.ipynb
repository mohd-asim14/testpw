# %%
1:
   ''' Given 
    T(n) = 3T(n-1) + 12n
    T(0) = 5
    find T(2) = ?
    
    
T(2) = 3T(2-1) + 12*2
     = 3T(1) + 24
T(1) = 3T(1-1) + 12*1
     = 3T(0) + 12
     
    here T(0) = 5 Substitude it
     = 3(5) + 12
     15 + 12 
     T(1) = 27
T(2) = 3(27) + 24
     = 81 + 24
     T(2) = 10''''

# %%
 ''''
 2:
 a. T(n) = T(n-1) + c
 
 = T((n-1)-1) + c + c 
   --> n-1 subsititude in T(n)
 = T(n-2) + 2c 
 = T((n-1)-2) + 2c + c
   --> again subsitude n-1 in T(n)
 = T(n-3) + 3c
  continue the processes
 = T(n-k) + k * c
 = T(n-(n-1)) + (n-1) * c
 = T(n-n+1) + (n-1) * c
 = T(1) + (n-1) * c
 T(n) = O(n)

# %%
'''
2:
b. T(n) = 2 T(n/2) + n

= 2  T(n/2) + n
= 2 T(n/2^2) + n + n
= 2 T(n/4) + 2n
= 2 T(n/4^2) + 2n + n
= 2 T(n/8) + 3n 
continue the processes
= 2 T(n/2^k) + k * n -----
here
n/2^k = 1
n = 2^k
log on bothe side 
log n =log 2 ^ k
log n = k log 2
k = log n

T(n) = T(n/2^log n ) + log n * n
T(n) = O(nlogn)

''''

# %%
'''
2:
c. T(n) = 2 T(n/2) + c

= 2 T(n/2) + c
= 2 T(n/2^2) + c + c
= 2 T(n/4) + 2c
= 2 T(n/4^2) + 2c +c
= 2 T(n/8) + 3c
continue the processes
= 2 T(n/2^k) + k * c ----
here
n/2^k = 1
n = 2^k
log on bothe side 
log n =log 2 ^ k
log n = k log 2
k = log n

T(n) = T(n/2^log n) + log n * c
T(n) = O(log n)

'''

# %%
''''
2:
c. T(n) = T(n/2) + c

= T(n/2) + c
= T(n/2^2) + c + c
= T(n/4) + 2c
= T(n/4^2) + 2c +c
= T(n/8) + 3c
continue the processes
= T(n/2^k) + k * c ----
here
n/2^k = 1
n = 2^k
log on bothe side 
log n =log 2 ^ k
log n = k log 2
k = log n

T(n) = T(n/2^log n) + log n * c
T(n) = O(log n)

# %%
'''
3:
2.

T(n) = 2T(n-1) + 1
                              
                                 
                                      n
                                    /   \
                                   /     \
                                  n-1    n-1
                                  /        \
                                 /          \
                                n-2         n-2
                                '            '
                                '            '
                                '            '
                                '            '
                                '            '
                                '            '
                                
                                T(n) = n

'''''

# %%
'''
3:
2.

T(n) = 2T(n) + 1
                              
                                 
                                      n
                                    /   \
                                   /     \
                                  n/2    n/2
                                  /        \
                                 /          \
                                n/4         n/4
                                '            '
                                '            '
                                '            '
                                '            '
                                '            '
                                '            '
                                
                                n/2^k = 1
                                n = 2^k
                                add log on both side
                                
                                log n = log 2^k
                                log n = k log 2
                                k = log n

'''''
